# %%
from db.setup_db import create_connection, create_database, create_tables

conn = create_connection()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/ds/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~/anaconda3/envs/ds/lib/python3.10/site-packages/sqlalchemy/pool/base.py:325, in Pool.connect(self)
#     318 """Return a DBAPI connection from the pool.
#     319
#     320 The connection is instrumented such that when its
#    (...)
#     323
#     324 """
# --> 325 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/ds/lib/python3.10/site-packages/sqlalchemy/pool/base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     887 if not fairy:
# --> 888     fairy = _ConnectionRecord.checkout(pool)
#     890     fairy._pool = pool
#
# ...

# %%
create_database(conn)
# Out:
# 2022-11-24 22:32:50,980 INFO sqlalchemy.engine.Engine CREATE DATABASE j2d;
# 2022-11-24 22:32:50,981 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 22:32:50,984 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# File ~/anaconda3/envs/ds/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/ds/lib/python3.10/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
# ...

# %%
conn.engine.execute('SELECT datname FROM pg_database;').fetchall()
# Out:
# 2022-11-24 22:27:29,659 INFO sqlalchemy.engine.Engine SELECT datname FROM pg_database;
# 2022-11-24 22:27:29,659 INFO sqlalchemy.engine.Engine [raw sql] {}
# [('postgres',), ('bass',), ('template1',), ('template0',), ('j2d',)]

# %%
conn.engine.url.database
# Out:
# 'j2d'

# %%
create_tables()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/wildbass/Documents/DataScience/Hackathons/j2d-22-hack/src/test.ipynb Celda 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/wildbass/Documents/DataScience/Hackathons/j2d-22-hack/src/test.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> create_tables()
#
# File ~/Documents/DataScience/Hackathons/j2d-22-hack/src/db/setup_db.py:30, in create_tables()
#      28 def create_tables():
#      29     with engine.connect() as con:
# ---> 30         with open("./db/table.sql") as file:
#      31             query = text(file.read())
#      32             con.execute(query)
#
# FileNotFoundError: [Errno 2] No such file or directory: './db/table.sql'

# %%
conn.engine.table_names()
# Out:
# 2022-11-24 22:42:11,779 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-11-24 22:42:11,780 INFO sqlalchemy.engine.Engine [cached since 31.61s ago] {'schema': 'public'}
# /var/folders/rn/zhfgrwvx4r94zbnzqwt6j76h0000gn/T/ipykernel_78011/825800579.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   conn.engine.table_names()
# ['center', 'demanda', 'product']

# %%
conn.execute('Select * from demanda')
# Out:
# 2022-11-24 22:42:31,050 INFO sqlalchemy.engine.Engine Select * from demanda
# 2022-11-24 22:42:31,051 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
import pandas as pd

data = pd.read_csv('../data/demanda.csv')
data.head()
# Out:
#    id  week  center_id  meal_id  checkout_price  base_price  \
# 0   1    30         68       24           11.72       87.34
# 1   2    52         63       86           47.44       29.61
# 2   3     2         32       76           16.35       96.42
# 3   4     1         81       84           55.17       61.72
# 4   5    20         73        1           24.55       26.53
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                  False               True           2
# 1                   True              False          19
# 2                  False               True          61
# 3                   True               True          72
# 4                  False               True          76

# %%
data.to_sql('demanda', conn, if_exists='replace')
# Out:
# 2022-11-24 22:56:47,889 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-24 22:56:47,891 INFO sqlalchemy.engine.Engine [generated in 0.00139s] {'name': 'demanda'}
# 2022-11-24 22:56:47,897 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-24 22:56:47,898 INFO sqlalchemy.engine.Engine [cached since 0.008301s ago] {'name': 'demanda'}
# 2022-11-24 22:56:47,903 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-11-24 22:56:47,904 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {'schema': 'public'}
# 2022-11-24 22:56:47,912 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
# ...

# %%
q = conn.execute('select * from demanda')
q.fetchone()
# Out:
# 2022-11-24 22:57:25,513 INFO sqlalchemy.engine.Engine select * from demanda
# 2022-11-24 22:57:25,514 INFO sqlalchemy.engine.Engine [raw sql] {}
# (0, 1, 30, 68, 24, 11.72, 87.34, False, True, 2)

# %%
data = pd.read_sql('select id, week, center_id from demanda', conn)
# Out:
# 2022-11-24 22:59:34,137 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-11-24 22:59:34,138 INFO sqlalchemy.engine.Engine [cached since 166.2s ago] {'name': 'select id, week, center_id from demanda'}
# 2022-11-24 22:59:34,146 INFO sqlalchemy.engine.Engine select id, week, center_id from demanda
# 2022-11-24 22:59:34,147 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
data.head()
# Out:
#    id  week  center_id
# 0   1    30         68
# 1   2    52         63
# 2   3     2         32
# 3   4     1         81
# 4   5    20         73

# %%
conn.engine.url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/wildbass/Documents/DataScience/Hackathons/j2d-22-hack/src/test.ipynb Celda 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/wildbass/Documents/DataScience/Hackathons/j2d-22-hack/src/test.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> conn.engine.url
#
# NameError: name 'conn' is not defined

# %%
from db.setup_db import prepare_everything

prepare_everything()
# Out:
# 2022-11-24 23:12:11,495 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-11-24 23:12:11,496 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 23:12:11,500 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-11-24 23:12:11,500 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 23:12:11,503 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-11-24 23:12:11,504 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 23:12:11,507 INFO sqlalchemy.engine.Engine commit
# 2022-11-24 23:12:11,508 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 23:12:11,511 INFO sqlalchemy.engine.Engine CREATE DATABASE j2d;
# 2022-11-24 23:12:11,511 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-11-24 23:12:11,514 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# ...
